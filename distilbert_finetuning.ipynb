# %%
from model.pipeline import TrainingPipeline
import pandas as pd
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\io\image.py:14: UserWarning: Failed to load image Python extension: '[WinError 127] No se encontró el proceso especificado'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_dataframe = pd.read_csv("./datos/train.csv")
valid_dataframe = pd.read_csv("./datos/dev.csv")
test_dataframe = pd.read_csv("./datos/dev.csv")

# %%
pipeline = TrainingPipeline(
    model_name="distilbert-base-uncased",
    train_dataframe=train_dataframe,
    valid_dataframe=valid_dataframe,
    test_dataframe=test_dataframe
)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
pipeline.train()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\training_args.py:1559: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# c:\Users\Admin\Desktop\contract_nli\model\pipeline.py:31: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#   0%|          | 0/8990 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pipeline.train()
#
# File c:\Users\Admin\Desktop\contract_nli\model\pipeline.py:39, in TrainingPipeline.train(self)
#      20 training_args = TrainingArguments(
#      21 output_dir=f"./output/{self.model_name}",
#      22     num_train_epochs=10,
#    (...)
#      29     evaluation_strategy="epoch",
#      30 )
#      31 trainer = Trainer(
#      32     model=self.model,
#      33     args=training_args,
#    (...)
#      37     compute_metrics=compute_metrics,
#      38 )
# ---> 39 trainer.train()
#      40 return {
#      41     "trainer":trainer,
#      42     "model":self.model,
#    (...)
#      46     "test_dataset":self.test_dataset
#      47 }
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\trainer.py:2122, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2120         hf_hub_utils.enable_progress_bars()
#    2121 else:
# -> 2122     return inner_training_loop(
#    2123         args=args,
#    2124         resume_from_checkpoint=resume_from_checkpoint,
#    2125         trial=trial,
#    2126         ignore_keys_for_eval=ignore_keys_for_eval,
#    2127     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\trainer.py:2474, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2471     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2473 with self.accelerator.accumulate(model):
# -> 2474     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2476 if (
#    2477     args.logging_nan_inf_filter
#    2478     and not is_torch_xla_available()
#    2479     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2480 ):
#    2481     # if loss is nan or inf simply add the average of previous logged losses
#    2482     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\trainer.py:3572, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3569     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3571 with self.compute_loss_context_manager():
# -> 3572     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3574 del inputs
#    3575 if (
#    3576     self.args.torch_empty_cache_steps is not None
#    3577     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3578 ):
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\trainer.py:3625, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3623         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3624     inputs = {**inputs, **loss_kwargs}
# -> 3625 outputs = model(**inputs)
#    3626 # Save past state if it exists
#    3627 # TODO: this needs to be fixed and made cleaner later.
#    3628 if self.args.past_index >= 0:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:978, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     970 r"""
#     971 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#     972     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#     973     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#     974     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#     975 """
#     976 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# --> 978 distilbert_output = self.distilbert(
#     979     input_ids=input_ids,
#     980     attention_mask=attention_mask,
#     981     head_mask=head_mask,
#     982     inputs_embeds=inputs_embeds,
#     983     output_attentions=output_attentions,
#     984     output_hidden_states=output_hidden_states,
#     985     return_dict=return_dict,
#     986 )
#     987 hidden_state = distilbert_output[0]  # (bs, seq_len, dim)
#     988 pooled_output = hidden_state[:, 0]  # (bs, dim)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:798, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     793     if self._use_sdpa and head_mask_is_none and not output_attentions:
#     794         attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     795             attention_mask, embeddings.dtype, tgt_len=input_shape[1]
#     796         )
# --> 798 return self.transformer(
#     799     x=embeddings,
#     800     attn_mask=attention_mask,
#     801     head_mask=head_mask,
#     802     output_attentions=output_attentions,
#     803     output_hidden_states=output_hidden_states,
#     804     return_dict=return_dict,
#     805 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:551, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     543     layer_outputs = self._gradient_checkpointing_func(
#     544         layer_module.__call__,
#     545         hidden_state,
#    (...)
#     548         output_attentions,
#     549     )
#     550 else:
# --> 551     layer_outputs = layer_module(
#     552         hidden_state,
#     553         attn_mask,
#     554         head_mask[i],
#     555         output_attentions,
#     556     )
#     558 hidden_state = layer_outputs[-1]
#     560 if output_attentions:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:495, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     492 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     494 # Feed Forward Network
# --> 495 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     496 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     498 output = (ffn_output,)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:429, in FFN.forward(self, input)
#     428 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 429     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\pytorch_utils.py:248, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     245     # concatenate output at same dimension
#     246     return torch.cat(output_chunks, dim=chunk_dim)
# --> 248 return forward_fn(*input_tensors)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:432, in FFN.ff_chunk(self, input)
#     431 def ff_chunk(self, input: torch.Tensor) -> torch.Tensor:
# --> 432     x = self.lin1(input)
#     433     x = self.activation(x)
#     434     x = self.lin2(x)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
